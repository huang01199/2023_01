# %%
import numpy as np
import pandas as pd
scores = np.random.randint(50,101,size=(50,5))
scores_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index = range(1,51)
             )
scores_pd
# Out:
#      國文   英文   數學   地理   歷史
# 1    58   80   52   78   64
# 2    61   73   54   80   81
# 3    57   60   68   97   88
# 4    96   80   54   99   75
# 5    95   65   66   61   84
# 6    54   58   70   86   98
# 7    99   92   77   58   92
# 8    96   82   85   84   56
# 9    93  100   56   67   71
# 10   95   90   72   57   93
# 11   94   58   69   98   63
# 12   84   75   91   91   77
# 13   75   55   65   84   90
# 14   68   72   75   50   51
# 15  100   99   61   60   96
# 16   57   78   72   66   71
# 17   73   55   84   61   63
# 18   52   88   65   57   86
# 19   87   66   97   71  100
# 20   96   51   56   56   77
# 21   62   85   69   70   86
# 22   67   63  100   72   98
# 23   93   89   52   99   88
# 24   71   75   82   88   54
# 25   85   99   90   54   70
# 26   86   94   50   98   69
# 27   78   89   79   83   60
# 28   66   60   55   82   66
# 29   94   92   65   85   84
# 30   92   82   59   72   85
# 31   57   84   81   68   85
# 32   70   90   62   94   87
# 33   90   65   76   72   68
# 34   64   64   50   80   98
# 35   93   74   71   90   53
# 36   67   84   61   89   66
# 37   53   62   75   67   76
# 38   70   65   76   64   98
# 39   53   81   74   86   56
# 40   83   51   93   81   61
# 41   57   96   92   67   60
# 42   74   54   97  100   84
# 43   95   97   94   87   83
# 44   91   64   96   88   53
# 45   73   68   88   52   83
# 46   61   96  100   79   55
# 47   97   55   51   51   75
# 48   67   57   60   59   91
# 49   61   80   85   90   80
# 50   98   68   89   83   50

# %%
def callback1(value:pd.Series):
    return pd.Series([value.max(),value.min(),value.median(),value.mean()],index=['最高分','最低分','中間值','平均值'])
    
dataFrame1 = scores_pd.apply(callback1)
dataFrame1
# Out:
#          國文     英文      數學      地理      歷史
# 最高分  100.00  100.0  100.00  100.00  100.00
# 最低分   52.00   51.0   50.00   50.00   50.00
# 中間值   74.50   75.0   72.00   79.50   77.00
# 平均值   77.16   75.2   73.22   76.22   75.96
